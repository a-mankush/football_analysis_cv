# %%
# !pip install roboflow
# Out:
# ...
#    ---------------------------------------- 0.0/76.9 kB ? eta -:--:--
#    --------------- ------------------------ 30.7/76.9 kB 660.6 kB/s eta 0:00:01
#    --------------------- ------------------ 41.0/76.9 kB 330.3 kB/s eta 0:00:01
#    --------------------- ------------------ 41.0/76.9 kB 330.3 kB/s eta 0:00:01
#    --------------------- ------------------ 41.0/76.9 kB 330.3 kB/s eta 0:00:01
#    ---------------------------------------- 76.9/76.9 kB 328.5 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/178.7 kB ? eta -:--:--
#    ------------------------- -------------- 112.6/178.7 kB 3.3 MB/s eta 0:00:01
#    ------------------------- -------------- 112.6/178.7 kB 3.3 MB/s eta 0:00:01
#    ------------------------- -------------- 112.6/178.7 kB 3.3 MB/s eta 0:00:01
#    ------------------------- -------------- 112.6/178.7 kB 3.3 MB/s eta 0:00:01
#    -------------------------------------  174.1/178.7 kB 751.6 kB/s eta 0:00:01
# ...

# %% [markdown]
# ## **Get Dataset**

# %%
from roboflow import Roboflow

rf = Roboflow(api_key="czMaaxiq7CQ6dYzohh7O")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to football-players-detection-1 in yolov5pytorch:: 100%|██████████| 1338/1338 [00:03<00:00, 399.24it/s]

# %%
import shutil

shutil.move(
    "football-players-detection-1/train",
    "football-players-detection-1/football-players-detection-1/train",
)
shutil.move(
    "football-players-detection-1/test",
    "football-players-detection-1/football-players-detection-1/test",
)
shutil.move(
    "football-players-detection-1/valid",
    "football-players-detection-1/football-players-detection-1/valid",
)
# Out:
# 'football-players-detection-1/football-players-detection-1/valid'

# %% [markdown]
# ## **Training**

# %%
# !yolo task=detect mode=train model=yolov5x.pt dataset="football-players-detection-1/data.yaml" epochs=100, imgsz=640

# %%
cd ..
# Out:
# c:\Users\aman kushwaha\Desktop\The\ML Project\footbool_analysis
# c:\Users\aman kushwaha\Desktop\The\my_environments\DS\Lib\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
pwd
# Out:
# 'c:\\Users\\aman kushwaha\\Desktop\\The\\ML Project\\footbool_analysis'

# %%
from utils import read_video, save_video
from trackers import Tracker

video_frames = read_video("input_videos/08fd33_4.mp4")

# %%
# Initialize the tracker
tracker = Tracker(model_path="models/best.pt")
tracks = tracker.get_object_tracks(video_frames)
# Out:
# 0: 384x640 1 ball, 1 goalkeeper, 18 players, 3 referees, 1057.7ms
# 1: 384x640 1 ball, 1 goalkeeper, 18 players, 3 referees, 1057.7ms
# 2: 384x640 1 goalkeeper, 18 players, 3 referees, 1057.7ms
# 3: 384x640 1 ball, 1 goalkeeper, 19 players, 3 referees, 1057.7ms
# Speed: 86.9ms preprocess, 1057.7ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 3
#       1 # Initialize the tracker
#       2 tracker = Tracker(model_path="models/best.pt")
# ----> 3 tracks = tracker.get_object_tracks(video_frames)
#
# File c:\Users\aman kushwaha\Desktop\The\ML Project\footbool_analysis\trackers\tracker.py:27, in Tracker.get_object_tracks(self, frames)
#      22 cls_name = detection.names  # {0: 'person', 1: 'car', ....}
#      23 cls_name_inv = {
#      24     v: k for k, v in cls_name.items()
# ...

# %%
from ultralytics import YOLO

model_path = "models/best.pt"
model = YOLO(model_path)

# %%
batch_size = 20
detections = []
for i in range(0, len(video_frames), batch_size):
    batch_detections = model.predict(video_frames[i : i + batch_size], conf=0.1)
    detections += batch_detections
# Out:
# 0: 384x640 1 ball, 1 goalkeeper, 18 players, 3 referees, 994.8ms
# 1: 384x640 1 ball, 1 goalkeeper, 18 players, 3 referees, 994.8ms
# 2: 384x640 1 goalkeeper, 18 players, 3 referees, 994.8ms
# 3: 384x640 1 ball, 1 goalkeeper, 19 players, 3 referees, 994.8ms
# 4: 384x640 1 goalkeeper, 19 players, 3 referees, 994.8ms
# 5: 384x640 1 goalkeeper, 18 players, 3 referees, 994.8ms
# 6: 384x640 1 goalkeeper, 19 players, 3 referees, 994.8ms
# 7: 384x640 1 ball, 1 goalkeeper, 19 players, 3 referees, 994.8ms
# 8: 384x640 1 ball, 1 goalkeeper, 19 players, 3 referees, 994.8ms
# 9: 384x640 1 ball, 1 goalkeeper, 19 players, 3 referees, 994.8ms
# 10: 384x640 1 goalkeeper, 20 players, 3 referees, 994.8ms
# 11: 384x640 1 goalkeeper, 20 players, 3 referees, 994.8ms
# 12: 384x640 21 players, 3 referees, 994.8ms
# 13: 384x640 21 players, 3 referees, 994.8ms
# 14: 384x640 1 ball, 20 players, 3 referees, 994.8ms
# 15: 384x640 1 ball, 19 players, 3 referees, 994.8ms
# ...

# %%
import supervision as sv

for i in detections:
    # print(i.boxes)
    print(sv.Detections.from_ultralytics(i))
# Out:
# Detections(xyxy=array([[     852.15,      633.93,      900.56,      721.15],
#        [     995.86,      453.26,      1027.1,      525.82],
#        [     1309.9,      446.97,      1350.8,      516.42],
#        [     1369.3,      815.61,      1444.4,      903.02],
#        [     222.34,      513.65,      255.44,       594.8],
#        [     533.17,      686.13,      579.12,      783.73],
#        [     588.96,      589.77,      631.24,      672.57],
#        [     1571.6,      611.28,      1611.6,      695.04],
#        [     374.24,      305.58,      400.65,      366.49],
#        [     329.27,      494.01,      364.28,      568.32],
#        [     872.26,      361.52,      905.36,      423.17],
#        [     1277.4,      393.05,      1306.9,      461.82],
#        [     360.13,      720.86,      394.47,      826.07],
#        [     1229.1,      430.92,      1263.8,       501.3],
#        [     1852.3,      808.38,      1893.6,      918.71],
# ...

# %%
tracker = Tracker(model_path="models/best.pt")
tracks = tracker.get_object_tracks(
    frames=video_frames, read_from_stub=True, stub_path="stubs/track_stubs.pkl"
)

# %%
tracks["players"]
# Out:
# [{1: {'bbox': [852.1503295898438,
#     633.9349975585938,
#     900.5601196289062,
#     721.1490478515625]},
#   2: {'bbox': [995.858642578125,
#     453.2625732421875,
#     1027.0504150390625,
#     525.8208618164062]},
#   3: {'bbox': [1309.9267578125,
#     446.96905517578125,
#     1350.761474609375,
#     516.4187622070312]},
#   4: {'bbox': [1369.312255859375,
#     815.608154296875,
#     1444.356201171875,
#     903.02490234375]},
#   5: {'bbox': [222.34451293945312,
#     513.6456298828125,
#     255.4354705810547,
#     594.7977905273438]},
#   6: {'bbox': [533.1693115234375,
#     686.1262817382812,
#     579.1179809570312,
#     783.7284545898438]},
#   7: {'bbox': [588.9558715820312,
#     589.7691650390625,
#     631.2390747070312,
#     672.5739135742188]},
#   8: {'bbox': [1571.6441650390625,
#     611.2783203125,
#     1611.6051025390625,
#     695.0421752929688]},
#   9: {'bbox': [374.241943359375,
#     305.582275390625,
#     400.64886474609375,
# ...

# %%
tracks = {
    "Players": [
        {
            "track_id i": {"bbox": [1, 2, 3, 4], "color": [3, 4, 5], "team": 1 / 0},
            "track_id i": {"bbox": [1, 2, 3, 4], "color": [3, 4, 5], "team": 1 / 0},
            "track_id i": {"bbox": [1, 2, 3, 4], "color": [3, 4, 5], "team": 1 / 0},
            "track_id i": {"bbox": [1, 2, 3, 4], "color": [3, 4, 5], "team": 1 / 0},
            "track_id i": {"bbox": [1, 2, 3, 4], "color": [3, 4, 5], "team": 1 / 0},
            "track_id i": {"bbox": [1, 2, 3, 4], "color": [3, 4, 5], "team": 1 / 0},
            "track_id i": {"bbox": [1, 2, 3, 4], "color": [3, 4, 5], "team": 1 / 0},
            "track_id i": {"bbox": [1, 2, 3, 4], "color": [3, 4, 5], "team": 1 / 0},
            "track_id i": {"bbox": [1, 2, 3, 4], "color": [3, 4, 5], "team": 1 / 0},
            "track_id i": {"bbox": [1, 2, 3, 4], "color": [3, 4, 5], "team": 1 / 0},
            "track_id i": {"bbox": [1, 2, 3, 4], "color": [3, 4, 5], "team": 1 / 0},
            "track_id i": {"bbox": [1, 2, 3, 4], "color": [3, 4, 5], "team": 1 / 0},
            "track_id i": {"bbox": [1, 2, 3, 4], "color": [3, 4, 5], "team": 1 / 0},
            "track_id i": {"bbox": [1, 2, 3, 4], "color": [3, 4, 5], "team": 1 / 0},
        },
        {
            "track_id i": {"bbox": [1, 2, 3, 4], "color": [3, 4, 5], "team": 1 / 0},
            "track_id i": {"bbox": [1, 2, 3, 4], "color": [3, 4, 5], "team": 1 / 0},
            "track_id i": {"bbox": [1, 2, 3, 4], "color": [3, 4, 5], "team": 1 / 0},
            "track_id i": {"bbox": [1, 2, 3, 4], "color": [3, 4, 5], "team": 1 / 0},
            "track_id i": {"bbox": [1, 2, 3, 4], "color": [3, 4, 5], "team": 1 / 0},
            "track_id i": {"bbox": [1, 2, 3, 4], "color": [3, 4, 5], "team": 1 / 0},
            "track_id i": {"bbox": [1, 2, 3, 4], "color": [3, 4, 5], "team": 1 / 0},
            "track_id i": {"bbox": [1, 2, 3, 4], "color": [3, 4, 5], "team": 1 / 0},
            "track_id i": {"bbox": [1, 2, 3, 4], "color": [3, 4, 5], "team": 1 / 0},
            "track_id i": {"bbox": [1, 2, 3, 4], "color": [3, 4, 5], "team": 1 / 0},
            "track_id i": {"bbox": [1, 2, 3, 4], "color": [3, 4, 5], "team": 1 / 0},
            "track_id i": {"bbox": [1, 2, 3, 4], "color": [3, 4, 5], "team": 1 / 0},
            "track_id i": {"bbox": [1, 2, 3, 4], "color": [3, 4, 5], "team": 1 / 0},
            "track_id i": {"bbox": [1, 2, 3, 4], "color": [3, 4, 5], "team": 1 / 0},
        },
    ],
    "referees": [{"track_id/referee_id ": {"bbox": [1, 2, 3, 4]}}],
}
